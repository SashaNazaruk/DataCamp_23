# %% [markdown]
# # Home task

# %% [markdown]
# ## Task about lakes
#
# - Generate 20 random variable from 1 to 100
# - Draw the plot of the  sequence
# - Lets assume each point represent the height and so all plotting is 2d mountains.
# - Then consider the unlimited rain from above - cavities become lakes full of water.
# - Determine the deepest lake

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
np.random.seed(2023)
a = np.random.randint(1,100,20)
a
# Out:
# array([88, 26, 71, 56, 34, 93,  4, 53, 87, 97, 23, 18, 54, 48, 78, 40, 70,
#        89,  4, 59])

# %%
b=np.array([5,1,2,3,10,4])
b
# Out:
# array([ 5,  1,  2,  3, 10,  4])

# %%
np.where(b == 4)[0]
# Out:
# array([5], dtype=int64)

# %%
plt.plot (a)
plt.xlabel('Індекс')
plt.ylabel('Значення')
plt.show()

# %% [markdown]
# ### Expected result
#
# You may present the result by  visualization or numbers that provide information about the boundaries of the lake and its deepest point

# %% [markdown]
# ### Sorted values

# %%
sorted_index = np.argsort(a)
sorted_values = a[sorted_index]
sorted_values
# Out:
# array([ 4,  4, 18, 23, 26, 34, 40, 48, 53, 54, 56, 59, 70, 71, 78, 87, 88,
#        89, 93, 97])

# %% [markdown]
# ### The boundaries of the lake

# %%
n = 2
print("the boundaries of the lake will be:",sorted_values[-n:])
# Out:
# the highest two points will be: [93 97]

# %%
y = sorted_values.index(sorted_values)
print("index of boundar", y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 y = sorted_values.index(sorted_values)
#       2 print("index of boundar", y)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
b = sorted_values[-n:]
b
# Out:
# array([93, 97])

# %%
plt.plot (a)
#
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 plt.plot (a)
# ----> 2 plt.plot (range(res[93],res[97]),res[6], c='red')
#
# NameError: name 'res' is not defined
